# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
CSV = pd.read_csv('train.csv')  # 读取训练数据
csv = CSV.copy()
print(csv.shape)  # (189, 9)
# 修改nan
# csv.fillna('NaN',inplace=True)
# Out:
# (1460, 81)

# %%
csv.columns.values
# Out:
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
# ...

# %% [markdown]
# # 修改nan

# %%
csv
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# print(csv['PoolArea'].value_counts(ascending=False).sort_values(ascending=False))
# print()
# print(csv['PoolArea'].value_counts(ascending=False)[0])  # 指的都是values_counts的counts
# print()
# print(csv['PoolArea'].value_counts(ascending=False).sort_values(ascending=False)[0])# 指的都是values_counts的counts
#                                                                                                                         # 所以左边index，右边value！！！
# print()
# print(csv['PoolArea'].value_counts(ascending=False).sort_values(ascending=False).index[0])
# print(csv['PoolArea'].value_counts(ascending=False).sort_values(ascending=False).values[0])

# print(" --------------  ")

# csv["LotFrontage"] = csv.groupby("Neighborhood")["LotFrontage"].transform(
#     lambda x: x.fillna(x.mean()))  # 这里的x是 LotFrontage每组数据  (根据Neighborhood组合的 )

# narray不支持median，而且narray的mean函数如果遇到nan也会得出nan！！！！！
# dataframe支持median，而且遇到nan会忽视，只计算有数值的 ！！！！！
# count = 0
# print(csv["LotFrontage"][10:13])
# print(csv["LotFrontage"][10:13].mean())

# %%
# 填充nil
features_fill_na_none = ['PoolQC','MiscFeature','Alley','Fence','FireplaceQu',
               'GarageQual','GarageCond','GarageFinish','GarageType',
               'BsmtExposure','BsmtCond','BsmtQual','BsmtFinType1','BsmtFinType2',
               'MasVnrType']

# 填充0
features_fill_na_0 = ['GarageYrBlt', 'GarageArea', 'GarageCars', 'MasVnrArea',
                      'BsmtFullBath','BsmtHalfBath', 'BsmtFinSF1', 'BsmtFinSF2', 
                      'BsmtUnfSF', 'TotalBsmtSF']

# 填众数
features_fill_na_mode = ["Functional", "MSZoning", "SaleType", "Electrical", 
                         "KitchenQual", "Exterior2nd", "Exterior1st"]

for feature_none in features_fill_na_none:
    csv[feature_none].fillna('None',inplace=True)
    
for feature_0 in features_fill_na_0:
    csv[feature_0].fillna(0,inplace=True)

for feature_mode in features_fill_na_mode:
    mode_value = csv[feature_mode].value_counts().sort_values(ascending=False).index[0]
    csv[features_fill_na_mode] = csv[features_fill_na_mode].fillna(mode_value)

# 用中值代替
csv["LotFrontage"] = csv.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))   # 这里的x是 LotFrontage每组数据  (根据Neighborhood组合的 )

# 像 Utilities 这种总共才两个值，同时有一个值是作为主要的，这种字段是无意义的，应该删除
csv.drop(['Utilities'], axis=1,inplace=True)

# %% [markdown]
# # 观察数据

# %%
# fig, ax = plt.subplots()
# ax.scatter(x = CSV['GrLivArea'], y = CSV['SalePrice'], c = "skyblue")
# plt.ylabel('SalePrice', fontsize=8)
# plt.xlabel('GrLivArea', fontsize=8)
# plt.show()

# print(csv.columns.values[1:csv.values.shape[1]-1])
# def FeatureDFrameScatter(DFrame, x_feature, y_feature, subf_x_num, subf_y_num, figsize=(20,80)):
#     n = subf_x_num*subf_y_num
# #     n =3 
#     count = 0
#     f, subf = plt.subplots()
#     for feature in x_feature:
#         if count < n:
#             subf.scatter(x = DFrame[feature], y = DFrame[y_feature[0]])
#         count+=1
#     if count < n:
#         subf.scatter([],[])
        
#     plt.show()

# FeatureDFrameScatter(csv.copy(), csv.columns.values[1:csv.values.shape[1]-1],['SalePrice'],27,3)

# %%
def FeatureValuesScatter(x,y,subf_x_num,subf_y_num, figsize=(20,80)):
    if x.ndim == 1:
        x=x.reshape(-1,1)
    if y.ndim == 1:
        y=y.reshape(-1,1)
    
    f, subf = plt.subplots(subf_x_num,subf_y_num,figsize=figsize)
    
    style_list = ["g+-", "r*-", "b.-", "yo-"]
    column = 0
    c = 0
    for i in range(subf_x_num):  
        for j in range(subf_y_num):
            if column<x.shape[1]:
                subf[i][j].scatter(x[:,column], y)
#                 subf[i][j].plot(x[:,column], y, style_list[c])
                c = (c+1)%len(style_list)
                column += 1
            else:
                subf[i][j].plot([],[])
                
    plt.show()
    
x =  np.array([i for i in range(csv.values.shape[1]-1)])

FeatureScatter(csv.values[:,x], csv.values[:,csv.values.shape[1]-1], 27,3)

# %%
import seaborn as sns
corrmat = CSV.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=1, square=True, ax=ax)  # square参数保证corrmat为非方阵时，图形整体输出仍为正方形

plt.show()

# %%
### 相关系数矩阵
corrmat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# # 数据清洗修补

# %%
CSV
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# 修改离散str数据
from sklearn.preprocessing import LabelEncoder
'''好像float处理不了'''

for j in range(csv.shape[1]):
    name = []
    if type(csv.values[0, j]) == type(''):
        class_le = LabelEncoder()
        csv[csv.columns.values[j]] = class_le.fit_transform(csv[csv.columns.values[j]])

# 逆映射
# class_le.inverse_transform(df[''])

# %%
csv
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0        1          60         3         65.0     8450       1      1
# 1        2          20         3         80.0     9600       1      1
# 2        3          60         3         68.0    11250       1      1
# 3        4          70         3         60.0     9550       1      1
# 4        5          60         3         84.0    14260       1      1
# ...    ...         ...       ...          ...      ...     ...    ...
# 1455  1456          60         3         62.0     7917       1      1
# 1456  1457          20         3         85.0    13175       1      1
# 1457  1458          70         3         66.0     9042       1      1
# 1458  1459          20         3         68.0     9717       1      1
# 1459  1460          20         3         75.0     9937       1      1
#
#       LotShape  LandContour  LotConfig  ...  PoolArea  PoolQC  Fence  \
# ...

# %% [markdown]
# # 选与Price相关性前十的特征做矩阵

# %%
# import heapq
# print(corrmat["SalePrice"].values.tolist())
### 这个没啥意义应该，因为相关系数有负数！！！！！！！！

k = 10
top10_index = corrmat.nlargest(k, "SalePrice").index
# top10_index = corrmat.nsmallest(k, "SalePrice").index
top10_mat = corrmat.loc[top10_index, top10_index]
fig,ax = plt.subplots(figsize=(8,8))

sns.set(font_scale=1.25)
sns.heatmap(top10_mat, annot=True, annot_kws={'size':12}, square=True)

# %%
var_set = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.set(font_scale=1.25)  # 设置横纵坐标轴的字体大小
sns.pairplot(csv[var_set])  # 7*7图矩阵
# 可在kind和diag_kind参数下设置不同的显示类型，此处分别为散点图和直方图，还可以设置每个图内的不同类型的显示
plt.show()

# %% [markdown]
# # 训练

# %%
csv_train = csv.values.copy()
X = csv_train[:,[i for i in range(1, csv_train.shape[1]-1)]]
y = csv_train[:,csv_train.shape[1]-1]

# %%
# X_train, y_train = X, y

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression

def PolynomialLogisticRegression(degree=1, n_components=0.9, C=0.1, penalty='l2', solver='liblinear'):
    return Pipeline([
            ("poly", PolynomialFeatures(degree=degree)),
#             ("std_scalert", StandardScaler()),
#             ("pca", PCA(n_components=n_components)),
            ("lin_reg", LinearRegression())
    ] )

# %%
lin_reg = PolynomialLogisticRegression()
lin_reg.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('poly',
#                  PolynomialFeatures(degree=1, include_bias=True,
#                                     interaction_only=False, order='C')),
#                 ('lin_reg',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
lin_reg.score(X_test, y_test)
# Out:
# 0.814034376692151
