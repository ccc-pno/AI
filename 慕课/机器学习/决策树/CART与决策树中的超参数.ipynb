# %% [markdown]
# ![Cart1.png](attachment:Cart1.png)

# %% [markdown]
# # ID3， C4.5， C5.0是其他实现决策树的方法

# %% [markdown]
# ![cart2.png](attachment:cart2.png)

# %% [markdown]
# # 需要通过调参数剪枝

# %% [markdown]
# ![cart3.png](attachment:cart3.png)

# %% [markdown]
# # CART 和 决策树的超参数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

X, y = datasets.make_moons(noise=0.25, random_state=666)

# %%
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()

# %% [markdown]
# # criterion: 默认gini

# %% [markdown]
# # max_depth: 树的最大深度

# %%
from sklearn.tree import DecisionTreeClassifier

dt_clf = DecisionTreeClassifier()  # criterion默认gini系数
dt_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# 绘制不规则决策边界的函数
def plot_decision_boundary(model, axis):
    
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1),
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]

    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)

    from matplotlib.colors import ListedColormap
    custom_cmap = ListedColormap(['#EF9A9A','#FFF59D','#90CAF9'])

    plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %%
plot_decision_boundary(dt_clf, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   app.launch_new_instance()

# %%
dt_clf2 = DecisionTreeClassifier(max_depth=2)  # 树的最大深度为2
dt_clf2.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
plot_decision_boundary(dt_clf2, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   app.launch_new_instance()

# %% [markdown]
# ## min_samples_split: 每个结点至少有...个样本点才继续划分下去, 应小于等于样本总数。越大越欠拟合。

# %%
dt_clf3 = DecisionTreeClassifier(min_samples_split=10)  
dt_clf3.fit(X, y)

plot_decision_boundary(dt_clf3, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   app.launch_new_instance()

# %% [markdown]
# # min_samples_leaf: 一个叶子结点有几个样本点，如果等于1，会非常敏感，会过拟合

# %%
dt_clf4 = DecisionTreeClassifier(min_samples_leaf=6)  
dt_clf4.fit(X, y)

plot_decision_boundary(dt_clf4, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   app.launch_new_instance()

# %%
dt_clf4 = DecisionTreeClassifier(min_samples_leaf=1)     # 如果等于1，会过拟合于某一个点，很极端
dt_clf4.fit(X, y)

plot_decision_boundary(dt_clf4, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   app.launch_new_instance()

# %% [markdown]
# # max_leaf_nodes，最多有几个叶子结点，越多模型越复杂，越会过拟合

# %%
dt_clf5 = DecisionTreeClassifier(max_leaf_nodes=4)
dt_clf5.fit(X, y)

plot_decision_boundary(dt_clf5, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0],  X[y==1,1])
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   app.launch_new_instance()

# %% [markdown]
# ![cart4.png](attachment:cart4.png)
