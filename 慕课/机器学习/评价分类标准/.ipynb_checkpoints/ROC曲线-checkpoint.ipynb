# %% [markdown]
# ![TPR.png](attachment:TPR.png)

# %% [markdown]
# ![FPR.png](attachment:FPR.png)

# %% [markdown]
# ### 下图可以看出：
# ### TPR：线右边的星 / 全部的星
# ### FPR：线左边的圆 / 全部的圆
#
# ### 理解：
# ### 我们为了提高TPR把阈值拉低，犯FPR错误的概率也提高了

# %% [markdown]
# ![TPR%5C%E5%85%B3%E7%B3%BB.png](attachment:TPR%5C%E5%85%B3%E7%B3%BB.png)

# %% [markdown]
# # 实现TPR、FPR

# %%
def TN(y_true, y_predict):
    assert len(y_true) == len(y_predict)
    return np.sum((y_true == 0) & (y_predict == 0))

def FP(y_true, y_predict):
    assert len(y_true) == len(y_predict)
    return np.sum((y_true == 0) & (y_predict == 1))

def FN(y_true, y_predict):
    assert len(y_true) == len(y_predict)
    return np.sum((y_true == 1) & (y_predict == 0))

def TP(y_true, y_predict):
    assert len(y_true) == len(y_predict)
    return np.sum((y_true == 1) & (y_predict == 1))

# %%
def TPR(y_true, y_predict):
    tp = TP(y_true, y_predict)
    fn = FN(y_true, y_predict)
    try:
        return tp / (tp + fn)
    except:
        return 0.

# %%
def FPR(y_true, y_predict):
    fp = FP(y_true, y_predict)
    tn = FN(y_true, y_predict)
    try:
        return fp / (fp + tn)
    except:
        return 0.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

digits = datasets.load_digits()
X = digits.data
y = digits.target.copy()

y[digits.target==9] = 1
y[digits.target!=9] = 0

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
decision_scores = log_reg.decision_function(X_test)
# Out:
# /Users/apple/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
fprs = []
tprs = []
thresholds = np.arange(np.min(decision_scores), np.max(decision_scores), 0.1)
for threshold in thresholds:
    y_predict = np.array(decision_scores >= threshold, dtype = 'int')
    fprs.append(FPR(y_test, y_predict))
    tprs.append(TPR(y_test, y_predict))

# %%
plt.plot(fprs, tprs)
plt.show()

# %% [markdown]
# ### scikit-learn中的ROC

# %%
from sklearn.metrics import roc_curve

fprs, tprs, thresholds = roc_curve(y_test, decision_scores)

# %%
fprs.shape
# Out:
# (24,)

# %%
tprs.shape
# Out:
# (24,)

# %%
thresholds.shape
# Out:
# (24,)

# %%
plt.plot(fprs, tprs)
plt.show()

# %% [markdown]
# ### 横轴fprs不变，纵轴tprs越高越好
# ### 所以可以用曲线下面的面积来衡量模型的好坏

# %% [markdown]
# ### scikit-learn中求ROC曲线的面积

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test, decision_scores)
# Out:
# 0.9830452674897119

# %% [markdown]
# ### ROC用来衡量模型的好坏，但是本身对数据有偏不太敏感
# ### 想看数据是否有偏，还需要看精确率和召回率
