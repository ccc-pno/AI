# %%
import numpy as np
# from sklearn.datasets import fetch_mldata
# 在最新版的 sklearn 中，fetch_mldata 被弃用，改为使用 fetch_openml 获得 MNIST 数据集
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml('mnist_784')
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in wrapper()
#      46             try:
# ---> 47                 return f()
#      48             except HTTPError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in _arff_load()
#     387
# --> 388             arff_file = _arff.loads(response.read().decode('utf-8'),
#     389                                     encode_nominal=encode_nominal,
#
# ~/opt/anaconda3/lib/python3.7/gzip.py in read(self, size)
#     275             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 276         return self._buffer.read(size)
#     277
#
# ~/opt/anaconda3/lib/python3.7/gzip.py in read(self, size)
#     481             if buf == b"":
# --> 482                 raise EOFError("Compressed file ended before the "
#     483                                "end-of-stream marker was reached")
#
# EOFError: Compressed file ended before the end-of-stream marker was reached
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6afe26331d9c> in <module>
# ----> 1 mnist = fetch_openml('mnist_784')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y)
#     632     # obtain the data
#     633     arff = _download_data_arff(data_description['file_id'], return_sparse,
# --> 634                                data_home)
#     635
#     636     # nominal attributes is a dict mapping from the attribute name to the
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in _download_data_arff(file_id, sparse, data_home, encode_nominal)
#     391         return arff_file
#     392
# --> 393     return _arff_load()
#     394
#     395
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in wrapper()
#      53                 if os.path.exists(local_path):
#      54                     os.unlink(local_path)
# ---> 55                 return f()
#      56         return wrapper
#      57     return decorator
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in _arff_load()
#     380     @_retry_with_clean_cache(url, data_home)
#     381     def _arff_load():
# --> 382         with closing(_open_openml_url(url, data_home)) as response:
#     383             if sparse is True:
#     384                 return_type = _arff.COO
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/datasets/openml.py in _open_openml_url(openml_path, data_home)
#     101                 if is_gzip(fsrc):
#     102                     with open(local_path, 'wb') as fdst:
# --> 103                         shutil.copyfileobj(fsrc, fdst)
#     104                 else:
#     105                     with gzip.GzipFile(local_path, 'wb') as fdst:
#
# ~/opt/anaconda3/lib/python3.7/shutil.py in copyfileobj(fsrc, fdst, length)
#      77     """copy data from file-like object fsrc to file-like object fdst"""
#      78     while 1:
# ---> 79         buf = fsrc.read(length)
#      80         if not buf:
#      81             break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     594
#     595                 temp_mvb = mvb[:chunk_left]
# --> 596                 n = self._safe_readinto(temp_mvb)
#     597                 mvb = mvb[n:]
#     598                 total_bytes += n
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _safe_readinto(self, b)
#     634                 n = self.fp.readinto(temp_mvb)
#     635             else:
# --> 636                 n = self.fp.readinto(mvb)
#     637             if not n:
#     638                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
