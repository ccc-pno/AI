# %% [markdown]
# # Boosting

# %% [markdown]
# ![bos.png](attachment:bos.png)

# %% [markdown]
# # Ada Boosting
# ### 每次增加未选中的点的权重

# %% [markdown]
# ![boosting2.png](attachment:boosting2.png)

# %% [markdown]
# # Gradient Boosting

# %% [markdown]
# ![GB.png](attachment:GB.png)

# %% [markdown]
# #### 绿色的线是新拟合的模型 mi ( hi )
# #### yi = y - mi
# #### ei = yi - mi  = y - mi 之和
# #### 不断减去拟合的线得到误差(e)，对e拟合得到新模型(m），m之和就是结果

# %% [markdown]
# ![GB2.png](attachment:GB2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

X, y = datasets.make_moons(n_samples=500, noise=0.3, random_state=42)

# %%
plt.scatter(X[y==0,0], X[y==0,1])
plt.scatter(X[y==1,0], X[y==1,1])
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# # AdaBoosting
# ## 需要传入基础模型

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=2), n_estimators=500)
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#                    base_estimator=DecisionTreeClassifier(class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=2,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort=False,
#                                                          random_state=None,
# ...

# %%
ada_clf.score(X_test, y_test)
# Out:
# 0.864

# %% [markdown]
# # Gradient Boosting
# ## 不需要传入基础模型，这里Gradient Boosting就是用决策树实现的

# %%
from sklearn.ensemble import GradientBoostingClassifier

# 因为基础是决策树，所以有max_depth
# n_estimators集成多少个子模型
gb_clf = GradientBoostingClassifier(max_depth=2, n_estimators=30)
gb_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=2,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=30,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
gb_clf.score(X_test, y_test)
# Out:
# 0.912

# %% [markdown]
# # Boosting 解决回归问题

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
