# %% [markdown]
# ## 将X**2也作为X的特征

# %% [markdown]
# ![%E5%A4%9A%E9%A1%B9%E5%BC%8F%E5%9B%9E%E5%BD%921.png](attachment:%E5%A4%9A%E9%A1%B9%E5%BC%8F%E5%9B%9E%E5%BD%921.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-3, 3, size = 100)
X = x.reshape(-1, 1)

# %%
y = 0.5 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = lin_reg.predict(X)

# %%
plt.scatter(x, y)
plt.plot(x, y_predict, color='r')
plt.show()

# %% [markdown]
# ## 解决方案，添加一个特征

# %%
(X**2).shape
# Out:
# (100, 1)

# %%
X2 = np.hstack([X, X**2])  #列增加的方向

# %%
X2.shape
# Out:
# (100, 2)

# %%
lin_reg2 = LinearRegression()
lin_reg2.fit(X2, y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict2[np.argsort(x)], color='r')
plt.show()

# %%
lin_reg2.coef_    # 根据X2，第一个系数是X的，第二个是X**2的
# Out:
# array([1.01967171, 0.50731324])

# %%
lin_reg2.intercept_
# Out:
# 1.7468601113415845
