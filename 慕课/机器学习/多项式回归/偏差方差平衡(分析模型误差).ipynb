# %% [markdown]
# # 偏差和方差定义

# %%
### 偏差是偏离中心
### 方差是分散

# %% [markdown]
# ![%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE%E5%AE%9A%E4%B9%89.png](attachment:%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE%E5%AE%9A%E4%B9%89.png)

# %% [markdown]
# # 模型误差

# %%
### 不可避免的误差一般来自于收集数据时不可避免的噪音

# %% [markdown]
# ![%E6%A8%A1%E5%9E%8B%E8%AF%AF%E5%B7%AE1.png](attachment:%E6%A8%A1%E5%9E%8B%E8%AF%AF%E5%B7%AE1.png)

# %% [markdown]
# # 偏差

# %%
### 还有可能来自于特征选择错误，但这不是机器学习讨论的主要方面

# %% [markdown]
# ![%E5%81%8F%E5%B7%AE1.png](attachment:%E5%81%8F%E5%B7%AE1.png)

# %% [markdown]
# # 方差

# %% [markdown]
# ![%E6%96%B9%E5%B7%AE.png](attachment:%E6%96%B9%E5%B7%AE.png)

# %% [markdown]
# # 偏差方差与机器学习算法的关系

# %% [markdown]
# ![%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE.png](attachment:%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE.png)

# %% [markdown]
# ![%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE2.png](attachment:%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE2.png)

# %% [markdown]
# ![%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE3.png](attachment:%E5%81%8F%E5%B7%AE%E5%92%8C%E6%96%B9%E5%B7%AE3.png)

# %% [markdown]
# # 解决高方差的手法

# %% [markdown]
# ![%E6%96%B9%E5%B7%AE1111.png](attachment:%E6%96%B9%E5%B7%AE1111.png)

# %%
### 模型正则化很重要
