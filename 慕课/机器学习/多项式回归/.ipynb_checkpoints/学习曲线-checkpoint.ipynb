# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(666)
x = np.random.uniform(-3.0, 3.0, size=100)
X = x.reshape(-1, 1)
y = 0.5 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 学习曲线

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10)

# %%
X_train.shape
# Out:
# (75, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

train_score = []
test_score = []
for i in range(1, 76):
    lin_reg = LinearRegression()
    lin_reg.fit(X_train[:i], y_train[:i])
    
    y_train_predict = lin_reg.predict(X_train[:i])
    train_score.append(mean_squared_error(y_train[:i], y_train_predict))
    
    y_test_predict = lin_reg.predict(X_test)
    test_score.append(mean_squared_error(y_test, y_test_predict))

# %%
plt.plot([i for i in range(1, 76)], np.sqrt(train_score), label='train')
plt.plot([i for i in range(1, 76)], np.sqrt(test_score), label='test')
plt.legend()
plt.show()

# %%
def plot_learning_curve(algo, X_train, X_test, y_train, y_test):
    
    train_score = []
    test_score = []
    for i in range(1, len(X_train)+1):
        algo.fit(X_train[:i], y_train[:i])
        
        y_train_predict = algo.predict(X_train[:i])
        train_score.append(mean_squared_error(y_train[:i], y_train_predict))
    
        y_test_predict = algo.predict(X_test)
        test_score.append(mean_squared_error(y_test, y_test_predict))
        
    plt.plot([i for i in range(1, 76)], np.sqrt(train_score), label='train')
    plt.plot([i for i in range(1, 76)], np.sqrt(test_score), label='test')
    plt.legend()
    plt.axis([0, len(X_train)+1, 0, 4])
    plt.show()
    
plot_learning_curve(LinearRegression(), X_train, X_test, y_train, y_test)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures 

def PolynomialRegression(degree):
    return Pipeline([
        ("poly", PolynomialFeatures(degree)),
        ("std_scalert", StandardScaler()),
        ("lin_reg", LinearRegression())
    ])

# %%
poly2_reg = PolynomialFeatures(degree=2)
plot_learning_curve(poly2_reg, X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f03dff810560> in <module>
#       1 poly2_reg = PolynomialFeatures(degree=2)
# ----> 2 plot_learning_curve(poly2_reg, X_train, X_test, y_train, y_test)
#
# <ipython-input-15-f0d7ba6a0a05> in plot_learning_curve(algo, X_train, X_test, y_train, y_test)
#       6         algo.fit(X_train[:i], y_train[:i])
#       7
# ----> 8         y_train_predict = algo.predict(X_train[:i])
#       9         train_score.append(mean_squared_error(y_train[:i], y_train_predict))
#      10
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'predict'
