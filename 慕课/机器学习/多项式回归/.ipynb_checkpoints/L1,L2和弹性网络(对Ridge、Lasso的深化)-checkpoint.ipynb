# %% [markdown]
# # 扩展到n维(底层数学思想相似)

# %% [markdown]
# ![%E6%AF%94%E8%BE%83Ridge%E5%92%8CLasso.png](attachment:%E6%AF%94%E8%BE%83Ridge%E5%92%8CLasso.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# # L0正则是个特例，但很少使用

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# # 常用的版本

# %%
### ridge虽然很难归零，但是计算量大
### Lasso会简化计算量，但是没有ridge准确

# %% [markdown]
# ![7.png](attachment:7.png)
